# %% [markdown]
# # Лабораторна робота №1
# **Тема:** Підготовка робочого середовища та ознайомлення з Jupyter Notebook.
# **Мета:** Налаштувати середовище та вивчити основні можливості Jupyter Notebook.

# %%
name = input("Введіть ваше ім'я: ")
print(f"Hello, {name}!")
# Out:
# Hello, Daria!

# %%
import numpy as np

array = np.random.randint(0, 100, 10)
print("Масив:", array)

mean_value = np.mean(array)
print("Середнє значення масиву:", mean_value)
# Out:
# Масив: [50 84 40 18  7 74 72 50 80 96]
# Середнє значення масиву: 57.1
